# %%
import importlib

# %%
import ListNode
import GraphAlgorithms
importlib.reload(ListNode)
importlib.reload(GraphAlgorithms)
from ListNode import ListNode

# %%
a,b,c,d,e,f,g,h,i,j,k,l = ListNode.create_many(
                            ["a","b","c","d","e","f","g","h","i", "j","k","l"])

a.append([b,e])
e.append([i,j])
i.append(j)
c.append([d,g,h])
d.append(h)
g.append([h,k])
h.append([k,l])
d_e = GraphAlgorithms.depth_first_search(
    [a,b,c,d,e,f,g,h,i,j,k])
ListNode.show_graph(d_e, True)

# %%
a.show()

# %%
copy_a = GraphAlgorithms.create_copy_of_graph(a)
copy_a.show()

# %%
d_e = GraphAlgorithms.depth_first_search([e])

# %%
ListNode.show_graph(d_e, True)
e.to_json()
# Out:
# {'val': 'e', 'next': ['f', 'g', 'h'], 'prev': [], 'pre': 0, 'post': 0}

# %%
d_a = GraphAlgorithms.depth_first_search([a,b,c,d,e,f,g,h,i,j])
c.to_json()
# Out:
# {'val': 'Hello', 'next': [], 'prev': [3], 'pre': 0, 'post': 0}

# %%
ListNode.show_graph(d_a, True)
