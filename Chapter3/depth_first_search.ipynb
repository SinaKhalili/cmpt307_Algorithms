# %%
import importlib

# %%
import ListNode
import GraphAlgorithms
importlib.reload(ListNode)
importlib.reload(GraphAlgorithms)
from ListNode import ListNode

# %%
a = ListNode(3)
b = ListNode(7)
c = ListNode('Hello')
d = ListNode('New')
a.append([b,c])
a.append(d)
b.append(d)
e,f,g,h = ListNode.create_many(['e','f','g','h'])
e.append([f,g,h])

# %%
e.show()

# %%
d_e = GraphAlgorithms.depth_first_search(e)

# %%
d_e.show()

# %%
d.clear()
d.edge('1, 2 \n Hey', 'Paul')
d.edge('Hello', 'Paul')

# %%
d

# %%
makeg()
